# %% [markdown]
# ### Evaluating the Quality-of-Life and Climate Sustainbility Tradeoff
# - This Jupyter Notebook will assess the relationship in a broad range of countries between years 1960 and 2022 between per-capita GDP and the following datasets:
# 	- CO2 emissions per capita
# 	- Access to basic water resources
# 	- Life expectancy at birth
# 	- Poverty rate
# - Correlative visualization is performed to showcase the overall relationship between the above datasets and per-capita GDP by country
# - A predictive model is used to estiamte future per-capita GDP using the above datasets

# %% [markdown]
# ### IMPORTS:

# %%
import cleaning.co2_gdp_corr as co2_gdp
import cleaning.life_expectancy_gdp_corr as life_expectancy_gdp
import cleaning.poverty_gdp_corr as poverty_gdp
import cleaning.water_access_gdp_corr as water_access_gdp
from prediction.predict_gdp_5yr_with_groups import run_prediction

# %% [markdown]
# ### Correlative Visualization

# %%
co2_gdp.run()
life_expectancy_gdp.run()
poverty_gdp.run()
water_access_gdp.run()

# %% [markdown]
# ### Predictive Model

# %%
run_prediction(DV_FILE_name='co2_pcap_cons.csv')
run_prediction(DV_FILE_name='life_expectancy_at_birth.csv')
run_prediction(DV_FILE_name='poverty_rate.csv')
run_prediction(DV_FILE_name='at_least_basic_water_source_overall_access_percent.csv')
# Out:
# Analysis for co2_per_capita:
#
# Dataset shape: (12033, 7)
#
# Missing values:
# gdp_per_capita           0
# co2_per_capita           0
# log_gdp                  0
# co2_per_capita_lag1    191
# dtype: int64
# merged_co2_pcap_cons_gdp.csv
#
# Processed dataset saved to: merged_co2_pcap_cons_gdp.csv
# Correlation matrix:
#                       log_gdp  co2_per_capita  co2_per_capita_lag1
# log_gdp              1.000000        0.719863             0.718315
# co2_per_capita       0.719863        1.000000             0.986229
# co2_per_capita_lag1  0.718315        0.986229             1.000000
#
# Linear regression results:
# Coefficient: 0.139655
# Intercept: 8.321503
# R^2: 0.515976
# === 5-Year GDP Prediction Model ===
# R^2: 0.9773
# RMSE: 0.1791
# Coefficients: {'log_gdp': np.float64(0.9996053416158994), 'co2_per_capita_lag1': np.float64(-0.0012191243713990964)}
# === Model Performance by GDP Group ===
# Low countries → R^2: 0.8237
# Middle countries → R^2: 0.7921
# ...
